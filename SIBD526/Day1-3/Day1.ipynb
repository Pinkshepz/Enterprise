# %%
A=5
B=A*10
print(B)
# Out:
# 50

# %%
name='Somying'
print(name)
# Out:
# Somying

# %%
print(name,B)
# Out:
# Somying 50

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
y=[3,2,4,3,4]
x=['Jan','Feb','Mar','Apr','May']
plt.bar(x,y)

# print("Lukpla")
# Out:
# <BarContainer object of 5 artists>

# %%
#IPython
import IPython
print("IPython version: %6.6s (need at least 1.0)" % IPython.__version__)

# !pip install jupyterlab
import jupyterlab
print("JupyterLab version: %6.6s (need at least 0.35.x)" % jupyterlab.__version__)

#Numpy
import numpy as np
print("Numpy version: %6.6s (need at least 1.7.1)" % np.__version__)
# Out:
# IPython version:  8.2.0 (need at least 1.0)
# ...
#   Attempting uninstall: pywinpty
#     Found existing installation: pywinpty 2.0.2
#     Uninstalling pywinpty-2.0.2:
#       Successfully uninstalled pywinpty-2.0.2
# JupyterLab version:  3.3.2 (need at least 0.35.x)
# Numpy version: 1.21.5 (need at least 1.7.1)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\66963\\anaconda3\\Lib\\site-packages\\~inpty\\winpty.cp39-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %%
# !pip install xlrd
#xlrd (read excel)
import xlrd
print("xlrd version: %6.6s (need at least 1.0.0)" % xlrd. __version__)

# !pip install pandas
#Pandas for data tables
import pandas as pd
print("Pandas version: %6.0s (need at least 0.23.0)" % pd. __version__)

#plotting
import matplotlib
print("Matplotlib version: %6.6s (need at least 1.2.1)" % matplotlib. __version__)
# Out:
# ...
#      -------------------------------------- 96.5/96.5 KB 791.7 kB/s eta 0:00:00
# ...
# xlrd version:  2.0.1 (need at least 1.0.0)
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the 'C:\Users\Art\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the 'C:\Users\Art\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# ...
#      ---------------------------------------- 10.7/10.7 MB 5.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 502.3/502.3 KB 4.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 14.8/14.8 MB 7.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 341.8/341.8 KB 3.5 MB/s eta 0:00:00
# ...
# Pandas version:        (need at least 0.23.0)
# ...

# %%
A = 5
B = 3
C = 8
A > B and A > C
# Out:
# False

# %%
A > B or A > C
# Out:
# True

# %%
(A > B) or (A > C)
# Out:
# True

# %%
price = 110
if price >= 100:
    print('Discount 5%')
print('done')
# Out:
# Discount 5%
# done

# %%
price = 90
if price >= 100:
	print('Discount 5%')
else:
	print('Discount 2%')
print('Bye')
# Out:
# Discount 2%
# Bye

# %%
temp = 32
if temp < 30:
	print("Fan off")
elif temp >= 30 and temp < 40:
	print("Small Fan")
else: 
	print("Turn on a Big Fan")
# Out:
# Small Fan

# %%
for count in range(3):
	print("Test for")
	print(count)
print("done")
# Out:
# Test for
# 0
# Test for
# 1
# Test for
# 2
# done

# %%
for v in range(4,6):
	print(v)
print("end of program ja")
# Out:
# 4
# 5
# end of program ja

# %%
count = 0
while count < 3:
	print("Hello ja! ")
	count = count + 1
# Out:
# Hello ja!
# Hello ja!
# Hello ja!

# %%
while True:
	print("Hello")
print("end of program ja")
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# ...
